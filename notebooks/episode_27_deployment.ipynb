# %% [markdown]
# # Episode 27 — Docker and Cloud Deployment
#
# > *'A RAG app nobody can visit is a RAG app nobody will hire you for.'*

# %%
# Show docker-compose.yml
from pathlib import Path
print(Path('docker-compose.yml').read_text())

# %%
print('Deployment commands:')
print()
print('# Local full stack:')
print('make up')
print()
print('# Deploy to Fly.io:')
print('fly launch')
print('fly deploy')
print()
print('# Deploy to Railway:')
print('railway init')
print('railway up')

# %% [markdown]
# ## Docker architecture
#
# ```
# docker-compose up
#   ├── postgres:16 (pgvector)  :5432
#   ├── api (FastAPI)           :8000
#   └── ui  (Streamlit)        :8501
# ```
#
# All services talk on an internal bridge network.
# Only ports 8000 and 8501 are exposed to the host.
#
# ## Next: Episode 28 — Capstone!
