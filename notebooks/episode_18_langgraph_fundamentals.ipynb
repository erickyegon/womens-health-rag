# %% [markdown]
# # Episode 18 — LangGraph Fundamentals
#
# > *'Why chains break in production and graphs don't.'*

# %%
import sys,json
from pathlib import Path
cwd=Path().resolve(); repo_root=cwd.parent if cwd.name=='notebooks' else cwd
sys.path.insert(0,str(repo_root/'src'))
from dotenv import load_dotenv; load_dotenv(repo_root/'.env',override=True)
print('ready')

# %%
# Install LangGraph
import subprocess,sys
subprocess.run([sys.executable,'-m','pip','install','--quiet','langgraph'],check=True)
print('✅ LangGraph installed')

# %%
# Build the graph and visualise the topology
from rag.agent.graph import build_graph
graph = build_graph()
print('Graph nodes:', list(graph.nodes))
print()
print('Graph compiled successfully ✅')
print('Trace it in LangSmith — set LANGCHAIN_TRACING_V2=true in .env')

# %%
# Run a simple query through the graph
from rag.agent.graph import run_agent
result = run_agent('What is the total fertility rate in Nigeria?')
print(f'Strategy:  {result.get("strategy")}')
print(f'Rewrites:  {result.get("rewrites",0)}')
print(f'Docs:      {len(result.get("graded_docs",[]))}')
print(f'Grounded:  {result.get("grounded")}')
print(f'\nAnswer: {str(result.get("answer",""))[:300]}')

# %% [markdown]
# ## Next: Episode 19 — Adaptive retrieval routing
