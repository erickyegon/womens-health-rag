# %% [markdown]
# # Episode 14 — Conversational RAG with Memory
#
# > *'Tell me more about that' — making RAG actually conversational.*

# %%
import sys,json
from pathlib import Path
cwd=Path().resolve(); repo_root=cwd.parent if cwd.name=='notebooks' else cwd
sys.path.insert(0,str(repo_root/'src'))
from dotenv import load_dotenv; load_dotenv(repo_root/'.env',override=True)
print('ready')

# %%
from rag.chains.conversational_chain import ConversationSession
session = ConversationSession(max_turns=5)
# Turn 1
a1 = session.ask('What is the total fertility rate in Nigeria?')
print('Q1: What is the TFR in Nigeria?')
print(f'A1: {a1[:300]}')
print()
# Turn 2 — relies on context
a2 = session.ask('How does that compare to Kenya?')
print('Q2: How does that compare to Kenya?')
print(f'A2: {a2[:300]}')
print()
print(f'History length: {len(session.history)} messages')

# %% [markdown]
# ## Next: Episode 15 — Advanced chunking (semantic + parent-child)
