# %% [markdown]
# # Episode 26 — Streamlit Frontend
#
# > *'Your interviewers will ask to see a demo. Give them one.'*
#
# The UI lives at `src/rag/ui/app.py`. Run it with:
# ```bash
# streamlit run src/rag/ui/app.py
# # or via docker-compose:
# make up  # → http://localhost:8501
# ```

# %%
# Show the UI file content
from pathlib import Path
print(Path('src/rag/ui/app.py').read_text()[:1000])
print('...')

# %% [markdown]
# ## Key UI features
# - Streaming token-by-token display
# - Country/year sidebar filters
# - Source citations panel (expandable)
# - Agent vs chain toggle
# - Conversation history
# - API health indicator
#
# ## Next: Episode 27 — Docker and cloud deployment
