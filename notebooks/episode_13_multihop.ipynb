# %% [markdown]
# # Episode 13 — Multi-hop Retrieval
#
# > *'How does female education affect child mortality?' requires two retrievals.*

# %%
import sys,json
from pathlib import Path
cwd=Path().resolve(); repo_root=cwd.parent if cwd.name=='notebooks' else cwd
sys.path.insert(0,str(repo_root/'src'))
from dotenv import load_dotenv; load_dotenv(repo_root/'.env',override=True)
print('ready')

# %%
from rag.chains.multihop_chain import MultiHopChain
chain  = MultiHopChain()
result = chain.invoke('How does female secondary education relate to under-5 child mortality in Kenya?')
print('Sub-questions decomposed:')
for q in result['sub_questions']: print(f'  - {q}')
print(f'\nDocs used: {result["docs_used"]}')
print(f'\nAnswer: {result["answer"][:400]}')

# %% [markdown]
# ## Next: Episode 14 — Conversational RAG
