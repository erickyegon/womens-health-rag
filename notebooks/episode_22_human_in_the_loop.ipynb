# %% [markdown]
# # Episode 22 — Human-in-the-Loop
#
# > *'For sensitive health questions, the agent pauses and waits for approval.'*

# %%
import sys,json
from pathlib import Path
cwd=Path().resolve(); repo_root=cwd.parent if cwd.name=='notebooks' else cwd
sys.path.insert(0,str(repo_root/'src'))
from dotenv import load_dotenv; load_dotenv(repo_root/'.env',override=True)
print('ready')

# %%
from rag.agent.checkpointer import get_memory_checkpointer, run_with_hitl
# Auto-approve demo (set auto_approve=False to see the human review prompt)
result = run_with_hitl(
    'What is the maternal mortality ratio in Ethiopia?',
    thread_id='hitl-demo-01',
    auto_approve=True,
)
print(f'Answer: {str(result.get("answer",""))[:300]}')

# %% [markdown]
# ## Next: Episode 23 — Multi-agent systems
