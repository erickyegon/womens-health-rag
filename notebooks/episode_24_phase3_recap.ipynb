# %% [markdown]
# # Episode 24 — Phase 3 Recap: The Full Agentic System
#
# > *'This is what you show in the interview.'*

# %%
import sys,json
from pathlib import Path
cwd=Path().resolve(); repo_root=cwd.parent if cwd.name=='notebooks' else cwd
sys.path.insert(0,str(repo_root/'src'))
from dotenv import load_dotenv; load_dotenv(repo_root/'.env',override=True)
print('ready')

# %%
# Full system demo — the interview showstopper
from rag.agent.graph import run_agent, stream_agent
question = 'How does female secondary education correlate with under-5 child mortality across our dataset?'
print(f'Complex multi-country question: {question}')
print()
for node_name, update in stream_agent(question):
    graded = len(update.get('graded_docs',[]))
    if graded: print(f'✓ Graded {graded} relevant docs')
    if update.get('strategy'): print(f'✓ Strategy: {update["strategy"]}')
    if update.get('answer'): print(f'✓ Answer generated ({len(update["answer"])} chars)')

# %% [markdown]
# ## Phase 3 complete
#
# You now have a:
# - Self-correcting, adaptive RAG agent
# - Full LangSmith observability
# - Human-in-the-loop capability
# - Multi-agent architecture demonstrated
#
# **Phase 4 (Episodes 25-28):** Ship it — FastAPI, Streamlit, Docker, cloud deploy.
