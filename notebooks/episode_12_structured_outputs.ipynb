# %% [markdown]
# # Episode 12 — Structured Outputs and Citations with Pydantic
#
# > *'Make the LLM give you typed data, not free text.'*

# %%
import sys,json
from pathlib import Path
cwd=Path().resolve(); repo_root=cwd.parent if cwd.name=='notebooks' else cwd
sys.path.insert(0,str(repo_root/'src'))
from dotenv import load_dotenv; load_dotenv(repo_root/'.env',override=True)
print('ready')

# %%
from rag.chains.structured_chain import invoke_structured, RAGResponse
result = invoke_structured('What is the TFR in Nigeria according to the 2021 DHS?')
print(type(result).__name__)
print(f'Answer:     {result.answer[:200]}')
print(f'Confidence: {result.confidence}')
print(f'Caveat:     {result.caveat}')
print(f'Sources:    {len(result.sources)}')
for s in result.sources:
    print(f'  [{s.n}] {s.title} | {s.country} {s.year} p{s.page}')

# %% [markdown]
# ## Next: Episode 13 — Multi-hop retrieval
